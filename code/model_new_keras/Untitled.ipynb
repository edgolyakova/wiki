# %%
import pandas as pd
import numpy as np
import string
from string import digits
import matplotlib.pyplot as plt
# %matplotlib inline
import re
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from keras.layers import Input, LSTM, Embedding, Dense
from keras.models import Model

# %%
lines = pd.read_csv('fr_pairs_2k_manual.csv')
lines
# Out:
#                                                      EN  \
# 0       In 1835 he met and befriended Taras Shevchenko.
# 1     Edward kept a camel as a pet and as a young ma...
# 2     Although it represents a limited activity toda...
# 3     In 1979 Gebhard (with Alan B. Johnson) conclud...
# 4     In 1998 the USAF's Lockheed U-2S fleet was fit...
# ...                                                 ...
# 1898  Nitta pinned under the dead horse and unable t...
# 1899              He was deployed to the Russian front.
# 1900  The telescope is remotely controllable from mu...
# 1901  With armistice declared of June 18 1940 he ref...
# 1902  For a long time this path constituted the only...
#
#                                                      FR
# 0     En juillet 1835 il rencontre et se lie avec Ta...
# 1     Édouard avait un chameau comme animal de compa...
# 2     Aujourd’hui réduite l’activité ferroviaire a é...
# 3     En 1979 Gebhard (avec Alan B. Johnson) a concl...
# 4     En 1998 la flotte américaine de Lockheed U-2 e...
# ...                                                 ...
# 1898  Nitta coincé sous le cheval mort et incapable ...
# 1899                  Il est appelé sur le front russe.
# 1900  Le télescope est contrôlé à distance grâce à d...
# 1901  À l'appel du 18 juin (1940) il refuse l'armist...
# 1902  Ce chemin constitua longtemps la seule voie ve...
#
# [1903 rows x 2 columns]

# %%
lines['EN'] = lines['EN'].apply(lambda x: x.lower())
lines
# Out:
#                                                      EN  \
# 0       in 1835 he met and befriended taras shevchenko.
# 1     edward kept a camel as a pet and as a young ma...
# 2     although it represents a limited activity toda...
# 3     in 1979 gebhard (with alan b. johnson) conclud...
# 4     in 1998 the usaf's lockheed u-2s fleet was fit...
# ...                                                 ...
# 1898  nitta pinned under the dead horse and unable t...
# 1899              he was deployed to the russian front.
# 1900  the telescope is remotely controllable from mu...
# 1901  with armistice declared of june 18 1940 he ref...
# 1902  for a long time this path constituted the only...
#
#                                                      FR
# 0     En juillet 1835 il rencontre et se lie avec Ta...
# 1     Édouard avait un chameau comme animal de compa...
# 2     Aujourd’hui réduite l’activité ferroviaire a é...
# 3     En 1979 Gebhard (avec Alan B. Johnson) a concl...
# 4     En 1998 la flotte américaine de Lockheed U-2 e...
# ...                                                 ...
# 1898  Nitta coincé sous le cheval mort et incapable ...
# 1899                  Il est appelé sur le front russe.
# 1900  Le télescope est contrôlé à distance grâce à d...
# 1901  À l'appel du 18 juin (1940) il refuse l'armist...
# 1902  Ce chemin constitua longtemps la seule voie ve...
#
# [1903 rows x 2 columns]
