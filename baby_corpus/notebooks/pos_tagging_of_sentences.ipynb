# %% [markdown]
# ## Spacy model installation / loading

# %%
# !pip install spacy
# !pip install spacy-transformers
# !python3 -m spacy download en_core_web_sm # change with the desired spacy model
import spacy
model = spacy.load("en_core_web_sm") # change with the desired spacy model

if model :
    print("Installation successful")
else:
    print("Installation error")
# Out:
# Requirement already satisfied: spacy in /home/clementinebleuze/.local/lib/python3.9/site-packages (3.4.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (2.28.1)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (8.1.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (2.0.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (1.0.3)
# Requirement already satisfied: packaging>=20.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (21.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (4.64.1)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy) (52.0.0)
# Requirement already satisfied: jinja2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (2.4.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (1.10.2)
# Requirement already satisfied: numpy>=1.15.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (1.23.3)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (3.3.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (3.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (0.10.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (1.0.9)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (0.4.2)
# Requirement already satisfied: pathy>=0.3.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy) (0.6.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from packaging>=20.0->spacy) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy) (0.0.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: spacy-transformers in /home/clementinebleuze/.local/lib/python3.9/site-packages (1.1.8)
# Requirement already satisfied: torch>=1.6.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy-transformers) (1.13.0)
# Requirement already satisfied: spacy<4.0.0,>=3.4.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy-transformers) (3.4.2)
# Requirement already satisfied: transformers<4.22.0,>=3.4.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy-transformers) (4.21.3)
# Requirement already satisfied: spacy-alignments<1.0.0,>=0.7.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy-transformers) (0.8.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy-transformers) (2.4.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.9)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (4.64.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.10.1)
# Requirement already satisfied: pathy>=0.3.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.6.2)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (0.4.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (21.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.0.7)
# Requirement already satisfied: jinja2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.3.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.0.3)
# Requirement already satisfied: numpy>=1.15.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.23.3)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (52.0.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (2.28.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (1.10.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<4.0.0,>=3.4.0->spacy-transformers) (8.1.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from packaging>=20.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<4.0.0,>=3.4.0->spacy-transformers) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<4.0.0,>=3.4.0->spacy-transformers) (4.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.1.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (0.0.3)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from torch>=1.6.0->spacy-transformers) (11.7.99)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from torch>=1.6.0->spacy-transformers) (8.5.0.96)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from torch>=1.6.0->spacy-transformers) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from torch>=1.6.0->spacy-transformers) (11.7.99)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->spacy-transformers) (0.34.2)
# Requirement already satisfied: filelock in /home/clementinebleuze/.local/lib/python3.9/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (3.8.0)
# Requirement already satisfied: regex!=2019.12.17 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (2022.9.13)
# Requirement already satisfied: pyyaml>=5.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (6.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (0.10.1)
# Requirement already satisfied: tokenizers!=0.11.3,<0.13,>=0.11.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from transformers<4.22.0,>=3.4.0->spacy-transformers) (0.12.1)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<4.0.0,>=3.4.0->spacy-transformers) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from jinja2->spacy<4.0.0,>=3.4.0->spacy-transformers) (2.1.1)
# Collecting en-core-web-sm==3.4.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.4.1/en_core_web_sm-3.4.1-py3-none-any.whl (12.8 MB)
#      |████████████████████████████████| 12.8 MB 6.0 MB/s eta 0:00:01                    | 1.5 MB 2.7 MB/s eta 0:00:05MB 6.0 MB/s eta 0:00:01
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from en-core-web-sm==3.4.1) (3.4.2)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.10)
# Requirement already satisfied: pathy>=0.3.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.6.2)
# Requirement already satisfied: jinja2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.1.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.64.1)
# Requirement already satisfied: numpy>=1.15.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.23.3)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.8)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (52.0.0)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.4.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.3.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.28.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.0.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.10.2)
# Requirement already satisfied: packaging>=20.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (21.3)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.4.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.0.9)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.10.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from packaging>=20.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pathy>=0.3.5->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (5.2.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (4.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2022.9.24)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (0.7.9)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from typer<0.5.0,>=0.3.0->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/clementinebleuze/.local/lib/python3.9/site-packages (from jinja2->spacy<3.5.0,>=3.4.0->en-core-web-sm==3.4.1) (2.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# Successful installation !

# %% [markdown]
# ## Loading of the file with sentence pairs

# %%
import pandas as pd
data = pd.read_csv("en_fr_pairs.csv") # change with the desired file (in the same folder, as a .csv)
data # check that everything's fine
# Out:
#                                                    EN  \
# 0   She advanced to the semi-final where she defea...
# 1   In 2008 Davidson was elected to the Naismith M...
# 2   Sterling raised in a poor family was a young a...
# 3   He treated in a masterly manner (Bulletin astr...
# 4   On February 26 2007 The Walt Disney Company an...
# ..                                                ...
# 95           (Morning Musume version) Koko ni Iruzee!
# 96                         The British Theatre Guide.
# 97  Minimal arrays containing all sub-array combin...
# 98                        I Raise My Eyes to Say Yes.
# 99     Does an entry have to be reporting on a union?
#
#                                                    FR   Good           POS EN  \
# 0   Elle avança aux semi-finales où elle gagna sur...   True              NaN
# 1   En 2008 Davidson fut intronisé au Naismith Mem...   True              NaN
# 2   Sterling élevé dans une famille pauvre était u...   True              NaN
# 3   Son traitement analytique de la capture des co...   True              NaN
# 4   Le 26 février 2007 The Walt Disney Company ann...   True              NaN
# ..                                                ...    ...              ...
# 95          Singles de Morning Musume Koko ni Iruzee!  False  meaning unclear
# 96                         The British Theatre Guide.  False     only english
# 97  Minimal arrays containing all sub-array combin...  False     only english
# 98      Pour les articles homonymes voir Dis-moi oui.  False                x
# 99  Ne faut-il donc aucun spectacle dans une Répub...  False                x
#
#     POS EN.1                                             POS FR
# 0        NaN  Elle PRON\navança VERB\naux ADP\nsemi-finales ...
# 1        NaN  En ADP\n2008 NUM\nDavidson PROPN\nfut AUX\nint...
# 2        NaN  Sterling PROPN\nélevé ADJ\ndans ADP\nune DET\n...
# 3        NaN  Son DET\ntraitement NOUN\nanalytique ADJ\nde A...
# 4        NaN  Le DET\n26 NUM\nfévrier NOUN\n2007 NUM\nThe X\...
# ..       ...                                                ...
# 95       NaN                                                NaN
# 96       NaN                                                NaN
# 97       NaN                                                NaN
# 98       NaN                                                NaN
# 99       NaN                                                NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# #### POS parsing

# %%
parsed = [] # list containing all of the POS-parsed sentences

for sentence, is_correct in zip(data["EN"], data["Good"]): # change columns names if needed
    s = ""
    if is_correct == True:
        parsed_sentence = model(sentence) # POS-parsing if sentence is well-aligned
        for token in parsed_sentence:
            s += f"{token} {token.pos_}\n"
    parsed.append(s)
    
print(parsed)
# Out:
# ["She PRON\nadvanced VERB\nto ADP\nthe DET\nsemi ADJ\n- ADJ\nfinal ADJ\nwhere SCONJ\nshe PRON\ndefeated VERB\nNew PROPN\nBrunswick PROPN\n's PART\nAndrea PROPN\nKelly PROPN\n. PUNCT\n", 'In ADP\n2008 NUM\nDavidson PROPN\nwas AUX\nelected VERB\nto ADP\nthe DET\nNaismith PROPN\nMemorial PROPN\nBasketball PROPN\nHall PROPN\nof ADP\nFame PROPN\nas ADP\na DET\ncontributor NOUN\nfor ADP\nhis PRON\nsuccesses NOUN\nas ADP\nan DET\nowner NOUN\nof ADP\nthe DET\nPistons PROPN\nand CCONJ\nShock PROPN\n. PUNCT\n', 'Sterling NOUN\nraised VERB\nin ADP\na DET\npoor ADJ\nfamily NOUN\nwas AUX\na DET\nyoung ADJ\nadventurer NOUN\nwith ADP\ndreams NOUN\nof ADP\nfame NOUN\nand CCONJ\nfortune NOUN\nwho PRON\ndecided VERB\nto PART\nbecome VERB\na DET\npirate NOUN\n. PUNCT\n', 'He PRON\ntreated VERB\nin ADP\na DET\nmasterly ADJ\nmanner NOUN\n( PUNCT\nBulletin PROPN\nastronomique ADJ\n1889 NUM\n) PUNCT\nthe DET\ntheory NOUN\nof ADP\nthe DET\ncapture NOUN\nof ADP\ncomets NOUN\nby ADP\nthe DET\nlarger ADJ\nplanets NOUN\nand CCONJ\nin ADP\nthis DET\nconnection NOUN\npublished VERB\nhis PRON\nvaluable ADJ\nCriterion PROPN\nfor ADP\nestablishing VERB\nthe DET\nidentity NOUN\nof ADP\na DET\nperiodic ADJ\ncomet NOUN\nwhatever PRON\nmay AUX\nhave AUX\nbeen AUX\nthe DET\nperturbations NOUN\nbrought VERB\nabout ADP\nin ADP\nits PRON\norbit NOUN\nbetween ADP\nsuccessive ADJ\nappearances NOUN\nby ADP\nthe DET\naction NOUN\nof ADP\na DET\nplanet NOUN\n. PUNCT\n', 'On ADP\nFebruary PROPN\n26 NUM\n2007 NUM\nThe DET\nWalt PROPN\nDisney PROPN\nCompany PROPN\nannounced VERB\nthat SCONJ\nfour NUM\nSouth ADJ\nAmerican ADJ\nversions NOUN\nof ADP\nthe DET\nshow NOUN\nwere AUX\nabout ADJ\nto PART\nbegin VERB\nproduction NOUN\n: PUNCT\none NUM\nfor ADP\nArgentina PROPN\none NUM\nfor ADP\nColombia PROPN\none NUM\nfor ADP\nEcuador PROPN\nand CCONJ\none NUM\nfor ADP\nBrazil PROPN\n. PUNCT\n', 'The DET\nMizo PROPN\nNational PROPN\nFamine PROPN\nFront PROPN\na DET\nbody NOUN\nformed VERB\nfor ADP\nfamine NOUN\nrelief NOUN\nin ADP\n1959 NUM\nlater ADV\ndeveloped VERB\ninto ADP\na DET\nnew ADJ\npolitical ADJ\norganisation NOUN\nthe DET\nMizo PROPN\nNational PROPN\nFront PROPN\n( PUNCT\nMNF PROPN\n) PUNCT\nin ADP\n1961 NUM\n. PUNCT\n', 'If SCONJ\nthe DET\nfive NUM\ncity NOUN\nlevels NOUN\nare AUX\npassed VERB\nthe DET\nplayer NOUN\nthen ADV\nfaces VERB\na DET\nbusiness NOUN\ncompetition NOUN\nwith ADP\nTrump PROPN\n. PUNCT\n', 'Between ADP\nlocations NOUN\nin ADP\nthe DET\nSolar PROPN\nSystem PROPN\nthe DET\nisotopic ADJ\ncomposition NOUN\nof ADP\nargon NOUN\nvaries VERB\ngreatly ADV\n. PUNCT\n', 'The DET\nroot NOUN\ncause NOUN\nof ADP\nour PRON\ncontemporary ADJ\ncultural ADJ\npoverty NOUN\nis AUX\nintellectual ADJ\ndishonesty NOUN\n. PUNCT\n', 'That PRON\n\'s AUX\nwhat PRON\nis AUX\nabsent ADJ\nfrom ADP\nHollywood PROPN\n\'s PART\ninterpretation NOUN\n. PUNCT\n" PUNCT\n', 'The DET\narea NOUN\nwas AUX\nbelonged VERB\nto ADP\nthe DET\nGuayos PROPN\ntribe NOUN\n. PUNCT\n', 'He PRON\nsaid VERB\nthat SCONJ\n" PUNCT\nwhile SCONJ\nthe DET\nLexicon PROPN\nin ADP\nits PRON\ncurrent ADJ\nstate NOUN\nis AUX\nnot PART\na DET\nfair ADJ\nuse NOUN\nof ADP\nthe DET\nHarry PROPN\nPotter PROPN\nworks VERB\nreference NOUN\nworks NOUN\nthat PRON\nshare VERB\nthe DET\nLexicon PROPN\n\'s PART\npurpose NOUN\nof ADP\naiding VERB\nreaders NOUN\nof ADP\nliterature NOUN\ngenerally ADV\nshould AUX\nbe AUX\nencouraged VERB\nrather ADV\nthan ADP\nstifled VERB\n. PUNCT\n" PUNCT\n', 'After ADP\nsix NUM\nmonths NOUN\nother ADJ\npossible ADJ\ncandidates NOUN\nhad AUX\nalso ADV\nfailed VERB\nand CCONJ\nProspero PROPN\nLambertini PROPN\nArchbishop PROPN\nof ADP\nBologna PROPN\nwho PRON\nhad AUX\nbeen AUX\na DET\ncardinal NOUN\nsince SCONJ\n9 NUM\nDecember PROPN\n1726 NUM\nwas AUX\nelected VERB\n. PUNCT\n', 'It PRON\nacted VERB\nineffectively ADV\nagainst ADP\na DET\nmilitary ADJ\nintervention NOUN\n. PUNCT\n', 'South PROPN\nAfrica PROPN\nresumed VERB\nofficial ADJ\ninternational ADJ\ncricket NOUN\nin ADP\n1991 NUM\nw ...

# %%
data["POS EN"] = parsed # change column name if needed
data # check that the annotations have been added
# Out:
#                                                    EN  \
# 0   She advanced to the semi-final where she defea...
# 1   In 2008 Davidson was elected to the Naismith M...
# 2   Sterling raised in a poor family was a young a...
# 3   He treated in a masterly manner (Bulletin astr...
# 4   On February 26 2007 The Walt Disney Company an...
# ..                                                ...
# 95           (Morning Musume version) Koko ni Iruzee!
# 96                         The British Theatre Guide.
# 97  Minimal arrays containing all sub-array combin...
# 98                        I Raise My Eyes to Say Yes.
# 99     Does an entry have to be reporting on a union?
#
#                                                    FR   Good  \
# 0   Elle avança aux semi-finales où elle gagna sur...   True
# 1   En 2008 Davidson fut intronisé au Naismith Mem...   True
# 2   Sterling élevé dans une famille pauvre était u...   True
# 3   Son traitement analytique de la capture des co...   True
# 4   Le 26 février 2007 The Walt Disney Company ann...   True
# ..                                                ...    ...
# 95          Singles de Morning Musume Koko ni Iruzee!  False
# 96                         The British Theatre Guide.  False
# 97  Minimal arrays containing all sub-array combin...  False
# 98      Pour les articles homonymes voir Dis-moi oui.  False
# 99  Ne faut-il donc aucun spectacle dans une Répub...  False
#
#                                                POS EN  POS EN.1  \
# 0   She PRON\nadvanced VERB\nto ADP\nthe DET\nsemi...       NaN
# 1   In ADP\n2008 NUM\nDavidson PROPN\nwas AUX\nele...       NaN
# 2   Sterling NOUN\nraised VERB\nin ADP\na DET\npoo...       NaN
# 3   He PRON\ntreated VERB\nin ADP\na DET\nmasterly...       NaN
# 4   On ADP\nFebruary PROPN\n26 NUM\n2007 NUM\nThe ...       NaN
# ..                                                ...       ...
# 95                                                          NaN
# 96                                                          NaN
# 97                                                          NaN
# 98                                                          NaN
# 99                                                          NaN
#
#                                                POS FR
# 0   Elle PRON\navança VERB\naux ADP\nsemi-finales ...
# 1   En ADP\n2008 NUM\nDavidson PROPN\nfut AUX\nint...
# 2   Sterling PROPN\nélevé ADJ\ndans ADP\nune DET\n...
# 3   Son DET\ntraitement NOUN\nanalytique ADJ\nde A...
# 4   Le DET\n26 NUM\nfévrier NOUN\n2007 NUM\nThe X\...
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
# [100 rows x 6 columns]

# %% [markdown]
# #### Export results

# %%
data.to_csv("en_fr_with_pos.csv", index=False) # change output file name with desired name
